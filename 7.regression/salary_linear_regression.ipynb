# %%
import pandas as pd
data = pd.read_csv('Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x1 = data.iloc[:,0]
type(x1)
x = data.iloc[:,0].values
type(x)
y = data.iloc[:,1].values

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)
plt.xlabel('Years Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Now we are required to find the line that fits this model. Here we will implement gradient descent to find the line of best fit.
# Some of the important links for its implementation-
# https://raw.githubusercontent.com/mattnedrich/GradientDescentExample/master/gradient_descent_example.gif
# Sum of squared distances formula-
# https://spin.atomicobject.com/wp-content/uploads/linear_regression_error1.png
# Partial derivative with respect to b and m to find gradient descent.

# %%
def compute_error_for_line_given_points(b, m, points):
    error = 0
    for i in range(len(points)):
        error += (points[i][1] - (m*points[i][0] + b))**2
    return error/len(points)

# %%
def step_gradient(b_current,m_current,pointys,learning_rate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    return [new_b, new_m]

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]

# %%
from numpy import *
#y = m*x + b where m is slope and b is y-intercept.
points = data.values
learning_rate = 0.0001
initial_b = 0
initial_m = 0
num_iterations = 1000
print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
print ("Running..........")
[b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_line_given_points(b, m, points)))
# Out:
# Starting gradient descent at b = 0, m = 0, error = 6502955270.733334
# Running..........
# After 1000 iterations b = 2915.204485601402, m = 12836.600965885045, error = 144401729.05898586

# %%
y2 = []
for i in range(len(points)):
    t = 0
    t = m*points[i][0] + b
    y2.append(t)

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Curve and Regression Line")
plt.show()

# %%
#Let's change the number of iterations and notice the effect:
num_iterations = 2000
[b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)

# %%
y2 = []
for i in range(len(points)):
    t = 0
    t = m*points[i][0] + b
    y2.append(t)

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Curve and Regression Line")
plt.show()

# %%
#Let's change it to 10,0000 and notice the effect
num_iterations = 10000
[b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)

# %%
y2 = []
for i in range(len(points)):
    t = 0
    t = m*points[i][0] + b
    y2.append(t)

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Curve and Regression Line")
plt.show()

# %%
# It is little bit more fitted. Let's change it to 20000
num_iterations = 10000
[b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
y2 = []
for i in range(len(points)):
    t = 0
    t = m*points[i][0] + b
    y2.append(t)
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Curve and Regression Line")
plt.show()

# %%
#Now Let's change it to 50,000 and notice the effect.
num_iterations = 10000
[b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
y2 = []
for i in range(len(points)):
    t = 0
    t = m*points[i][0] + b
    y2.append(t)
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Curve and Regression Line")
plt.show()

# %%
#
